# %%
source('../common.r')

# %%
d <- data.rubis(where="name = 'v0.28.2-sampa-sampled' and samples_txn_rate is not null and samples_txn_rate != '{}' and mix = 'bid-heavy' and phasing = 1")
# Out:
# Loading required package: tcltk
# The following `from` values were not present in `x`: 0
# The following `from` values were not present in `x`: rw#NA, simple#NA
# The following `from` values were not present in `x`: rw#NA, simple#NA
# The following `from` values were not present in `x`: rw#0#off, simple#0#off, simple#1#off

# %%
nrow(d)
# Out:
# [1] 3

# %%
samples <- adply(d, 1, function(r){
  s <- subset(r, select=c('id','cc','phasing','cc_ph','mix'))
  h <- to.hist(jsfix(r$samples_txn_rate))
  h$x <- h$x / 1e6 # convert to seconds
  data.frame(s, h)
})
samples$x <- ave(samples$x, cut(samples$x, 60*3))
samples$y <- samples$y * 4 # mult by nclients for total
samples <- subset(samples, x > 14 & x < 46)
# Out:
# Warning message:
# In data.frame(s, h): row names were found from a short variable and have been discardedWarning message:
# In data.frame(s, h): row names were found from a short variable and have been discardedWarning message:
# In data.frame(s, h): row names were found from a short variable and have been discarded

# %%
  ggplot(samples, aes(
    x = x,
    y = y,
    color = cc_ph, fill = cc_ph
  ))+
    xlab('execution time (s)')+
    ylab('throughput (txn/s)')+
    stat_summary(geom='line', fun.y=mean, size=0.4)+
    scale_x_continuous()+
    scale_y_continuous(labels = function(x){ x/1000+'k' })+
    cc_ph_scales(name = '', guide = guide_legend(nrow = 1))+
    coord_cartesian(xlim=c(15,45))+
    my_theme()+legend.bottom()+theme(legend.margin = unit(-25,'pt'), legend.background = element_rect(fill=alpha('white', 0)), legend.key.width = unit(16,'pt'))
# Out:
# plot without title

# %%
library(TTR)

# %%
samples <- ddply(samples, .(x,cc_ph), summarize, y = mean(y))
nrow(samples)
# Out:
# [1] 288

# %%
s <- subset(samples, cc_ph == COMB+PH)
data.frame(subset(s, select=c('cc_ph','x','y')), var = runMean(s$y, n = 10))
# Out:
# Warning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generatedWarning message:
# In `[<-.factor`(`*tmp*`, ri, value = "⋮"): invalid factor level, NA generated
#                                  cc_ph      x        y      var
# 1   boosting\n + combining\n + phasing 14.250 12208.15       NA
# 4   boosting\n + combining\n + phasing 14.580 12879.90       NA
# 7   boosting\n + combining\n + phasing 14.910 12288.09       NA
# 10  boosting\n + combining\n + phasing 15.240 12005.20       NA
# 13  boosting\n + combining\n + phasing 15.570 12480.72       NA
# 16  boosting\n + combining\n + phasing 15.900 12401.30       NA
# 19  boosting\n + combining\n + phasing 16.230 12445.89       NA
# 22  boosting\n + combining\n + phasing 16.575 11971.91       NA
# 25  boosting\n + combining\n + phasing 16.920 12829.23       NA
# 28  boosting\n + combining\n + phasing 17.250 12744.60 12425.50
# 31  boosting\n + combining\n + phasing 17.580 12413.73 12446.06
# 34  boosting\n + combining\n + phasing 17.910 12460.69 12404.14
# 37  boosting\n + combining\n + phasing 18.240 12259.73 12401.30
# 40  boosting\n + combining\n + phasing 18.570 12650.60 12465.84
# 43  boosting\n + combining\n + phasing 18.900 12359.46 12453.71
# 46  boosting\n + combining\n + phasing 19.245 12460.86 12459.67
# 49  boosting\n + combining\n + phasing 19.590 11718.49 12386.93
# 52  boosting\n + combining\n + phasing 19.920 12322.43 12421.98
# 55  boosting\n + combining\n + phasing 20.250 12441.83 12383.24
# 58  boosting\n + combining\n + phasing 20.580 12488.76 12357.66
# 61  boosting\n + combining\n + phasing 20.910 12737.78 12390.06
# 64  boosting\n + combining\n + phasing 21.240 12475.99 12391.59
# 67  boosting\n + combining\n + phasing 21.570 12984.07 12464.03
# 70  boosting\n + combining\n + phasing 21.915 12787.28 12477.70
# 73  boosting\n + combining\n + phasing 22.260 13120.21 12553.77
# 76  boosting\n + combining\n + phasing 22.590 12857.95 12593.48
# 79  boosting\n + combining\n + phasing 22.920 12549.83 12676.61
# 82  boosting\n + combining\n + phasing 23.250 12887.09 12733.08
# 85  boosting\n + combining\n + phasing 23.580 13270.75 12815.97
# 88  boosting\n + combining\n + phasing 23.910 13019.22 12869.02
# 91  boosting\n + combining\n + phasing 24.240 13160.95 12911.33
# 94  boosting\n + combining\n + phasing 24.585 12460.81 12909.82
# 97  boosting\n + combining\n + phasing 24.930 12823.32 12893.74
# 100 boosting\n + combining\n + phasing 25.260 12518.42 12866.85
# 103 boosting\n + combining\n + phasing 25.590 13411.14 12895.95
# 106 boosting\n + combining\n + phasing 25.920 13014.38 12911.59
# 109 boosting\n + combining\n + phasing 26.250 13686.91 13025.30
# 112 boosting\n + combining\n + phasing 26.580 13628.54 13099.44
# 115 boosting\n + combining\n + phasing 26.910 13374.76 13109.84
# 118 boosting\n + combining\n + phasing 27.255 12905.80 13098.50
# 121 boosting\n + combining\n + phasing 27.600 13206.11 13103.02
# 124 boosting\n + combining\n + phasing 27.930 13104.06 13167.34
# 127 boosting\n + combining\n + phasing 28.260 13047.65 13189.78
# 130 boosting\n + combining\n + phasing 28.590 13495.38 13287.47
# 133 boosting\n + combining\n + phasing 28.920 13237.70 13270.13
# 136 boosting\n + combining\n + phasing 29.250 13183.88 13287.08
# 139 boosting\n + combining\n + phasing 29.580 12675.44 13185.93
# 142 boosting\n + combining\n + phasing 29.925 13173.58 13140.44
# 145 boosting\n + combining\n + phasing 30.270 13643.26 13167.29
# 148 boosting\n + combining\n + phasing 30.600 13145.81 13191.29
# 151 boosting\n + combining\n + phasing 30.930 12929.16 13163.59
# 154 boosting\n + combining\n + phasing 31.260 13332.95 13186.48
# 157 boosting\n + combining\n + phasing 31.590 13417.25 13223.44
# 160 boosting\n + combining\n + phasing 31.920 13487.87 13222.69
# 163 boosting\n + combining\n + phasing 32.250 13770.77 13276.00
# 166 boosting\n + combining\n + phasing 32.580 13792.04 13336.81
# 169 boosting\n + combining\n + phasing 32.925 13985.08 13467.78
# 172 boosting\n + combining\n + phasing 33.270 14059.42 13556.36
# 175 boosting\n + combining\n + phasing 33.600 14547.42 13646.78
# 178 boosting\n + combining\n + phasing 33.930 14304.56 13762.65
# 181 boosting\n + combining\n + phasing 34.260 14346.09 13904.34
# 184 boosting\n + combining\n + phasing 34.590 14192.60 13990.31
# 187 boosting\n + combining\n + phasing 34.920 14058.57 14054.44
# 190 boosting\n + combining\n + phasing 35.250 14085.00 14114.16
# 193 boosting\n + combining\n + phasing 35.595 13749.01 14111.98
# 196 boosting\n + combining\n + phasing 35.940 13914.33 14124.21
# 199 boosting\n + combining\n + phasing 36.270 14147.58 14140.46
# 202 boosting\n + combining\n + phasing 36.600 13940.61 14128.58
# 205 boosting\n + combining\n + phasing 36.930 13953.15 14069.15
# 208 boosting\n + combining\n + phasing 37.260 14192.05 14057.90
# 211 boosting\n + combining\n + phasing 37.590 14233.17 14046.61
# 214 boosting\n + combining\n + phasing 37.920 14419.09 14069.26
# 217 boosting\n + combining\n + phasing 38.265 14042.57 14067.66
# 220 boosting\n + combining\n + phasing 38.610 14124.99 14071.65
# 223 boosting\n + combining\n + phasing 38.940 14418.32 14138.59
# 226 boosting\n + combining\n + phasing 39.270 14425.73 14189.73
# 229 boosting\n + combining\n + phasing 39.600 14415.92 14216.56
# 232 boosting\n + combining\n + phasing 39.930 14334.67 14255.97
# 235 boosting\n + combining\n + phasing 40.260 13673.06 14227.96
# 238 boosting\n + combining\n + phasing 40.590 13761.55 14184.91
# 241 boosting\n + combining\n + phasing 40.935 14467.65 14208.35
# 244 boosting\n + combining\n + phasing 41.280 13910.44 14157.49
# 247 boosting\n + combining\n + phasing 41.610 14417.71 14195.00
# 250 boosting\n + combining\n + phasing 41.940 14323.11 14214.82
# 253 boosting\n + combining\n + phasing 42.270 14309.51 14203.93
# 256 boosting\n + combining\n + phasing 42.600 14330.42 14194.40
# 259 boosting\n + combining\n + phasing 42.930 14371.10 14189.92
# 262 boosting\n + combining\n + phasing 43.260 14275.65 14184.02
# 265 boosting\n + combining\n + phasing 43.605 14289.12 14245.63
# 268 boosting\n + combining\n + phasing 43.950 14139.56 14283.43
# 271 boosting\n + combining\n + phasing 44.280 13670.39 14203.70
# 274 boosting\n + combining\n + phasing 44.610 13771.10 14189.77
# 277 boosting\n + combining\n + phasing 44.940 13812.09 14129.20
# 280 boosting\n + combining\n + phasing 45.270 13425.98 14039.49
# 283 boosting\n + combining\n + phasing 45.600 13744.37 13982.98
# 286 boosting\n + combining\n + phasing 45.930 12809.59 13830.90

# %%
ddply(na.omit(samples), .(cc_ph), summarize, mean_sd = sd(y))
# Out:
#                                cc_ph   mean_sd
# 1 boosting\n + combining\n + phasing  743.4324
# 2               boosting\n + phasing  734.8474
# 3              r/w locks\n + phasing 1356.0506

# %%
var <- function(s) runSD(s$y, n = 15)

s <- subset(samples, cc_ph == COMB+PH)
s.comb <- data.frame(s, var = var(s))
s <- subset(samples, cc_ph == COMM+PH)
s.comm <- data.frame(s, var = var(s))
s <- subset(samples, cc_ph == RW+PH)
s.rw <- data.frame(s, var = var(s))
s <- rbind(s.comb, s.comm, s.rw)
    
ddply(na.omit(s), .(cc_ph), summarize, mean_sd = mean(var))
# Out:
#                                cc_ph  mean_sd
# 1 boosting\n + combining\n + phasing 310.8772
# 2               boosting\n + phasing 287.4268
# 3              r/w locks\n + phasing 800.5425

# %%
  ggplot(s, aes(
    x = x,
    y = var,
    color = cc_ph, fill = cc_ph
  ))+
    xlab('execution time (s)')+
    ylab('throughput (txn/s)')+
    stat_summary(geom='line', fun.y=mean, size=0.4)+
    scale_x_continuous()+
    scale_y_continuous(labels = function(x){ x/1000+'k' })+
    cc_ph_scales(name = '', guide = guide_legend(nrow = 1))+
    coord_cartesian(xlim=c(15,45))+
    my_theme()+legend.bottom()+theme(legend.margin = unit(-25,'pt'), legend.background = element_rect(fill=alpha('white', 0)), legend.key.width = unit(16,'pt'))
# Out:
# Warning message:
# : Removed 42 rows containing missing values (stat_summary).
# plot without title
